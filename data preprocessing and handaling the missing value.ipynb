# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("dataset/titanic.csv")

# %%
a.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
a.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
a.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
a.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
a.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
a.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 886         True      True    True  True  True   True   True   True    True
# 887         True      True    True  True  True   True   True   True    True
# 888         True      True    True  True  True  False   True   True    True
# 889         True      True    True  True  True   True   True   True    True
# 890         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True  False      True
# ...

# %%
a.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# # Keep the missing values as it is

# %% [markdown]
# # Remove data object with missing value

# %%
a.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.dropna(thresh=11)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.dropna(thresh=12)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 9a# remove the object with thresold

# %%
a.dropna(thresh=int(0.6*len(a)))
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# # Remove the attribute with thresold

# %%
a.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
a.dropna(axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.dropna(axis=1,thresh=int(0.6*len(a)))
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a=(input("Enter your name:="))
b=a.upper()
if a == int:
    print("not valed")
else:
    print("valied")
print(b)
# Out:
# Enter your name:=Pooja
# valied
# POOJA

# %% [markdown]
# # handling the missing values

# %%
a=pd.read_csv("dataset/titanic.csv",usecols=["Survived","Age","Fare","Cabin"])

# %%
a.head()
# Out:
#    Survived   Age     Fare Cabin
# 0         0  22.0   7.2500   NaN
# 1         1  38.0  71.2833   C85
# 2         1  26.0   7.9250   NaN
# 3         1  35.0  53.1000  C123
# 4         0  35.0   8.0500   NaN

# %%
a.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# Cabin       687
# dtype: int64

# %%
b=a.fillna(0)

# %%
b.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# Cabin       0
# dtype: int64

# %%
c=a.fillna(method="ffill")
c.head()
# Out:
#    Survived   Age     Fare Cabin
# 0         0  22.0   7.2500   NaN
# 1         1  38.0  71.2833   C85
# 2         1  26.0   7.9250   C85
# 3         1  35.0  53.1000  C123
# 4         0  35.0   8.0500  C123

# %%
c.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# Cabin       1
# dtype: int64

# %%
d=a.fillna(method="bfill")
d.tail()
# Out:
#      Survived   Age   Fare Cabin
# 886         0  27.0  13.00   B42
# 887         1  19.0  30.00   B42
# 888         0  26.0  23.45  C148
# 889         1  26.0  30.00  C148
# 890         0  32.0   7.75   NaN

# %%
d.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# Cabin       1
# dtype: int64

# %%
e=a.fillna(method="bfill",limit=1)
e
# Out:
#      Survived   Age     Fare Cabin
# 0           0  22.0   7.2500   C85
# 1           1  38.0  71.2833   C85
# 2           1  26.0   7.9250  C123
# 3           1  35.0  53.1000  C123
# 4           0  35.0   8.0500   NaN
# ..        ...   ...      ...   ...
# 886         0  27.0  13.0000   B42
# 887         1  19.0  30.0000   B42
# 888         0  26.0  23.4500  C148
# 889         1  26.0  30.0000  C148
# 890         0  32.0   7.7500   NaN
#
# [891 rows x 4 columns]

# %%
e.isnull().sum()
# Out:
# Survived      0
# Age          26
# Fare          0
# Cabin       527
# dtype: int64

# %%
c=a.interpolate(method="linear")
c
# Out:
#      Survived   Age     Fare Cabin
# 0           0  22.0   7.2500   NaN
# 1           1  38.0  71.2833   C85
# 2           1  26.0   7.9250   NaN
# 3           1  35.0  53.1000  C123
# 4           0  35.0   8.0500   NaN
# ..        ...   ...      ...   ...
# 886         0  27.0  13.0000   NaN
# 887         1  19.0  30.0000   B42
# 888         0  22.5  23.4500   NaN
# 889         1  26.0  30.0000  C148
# 890         0  32.0   7.7500   NaN
#
# [891 rows x 4 columns]

# %%
c.isnull().sum()
# Out:
# Survived      0
# Age           0
# Fare          0
# Cabin       687
# dtype: int64

# %%
f=a.dropna()
f
# Out:
#      Survived   Age     Fare        Cabin
# 1           1  38.0  71.2833          C85
# 3           1  35.0  53.1000         C123
# 6           0  54.0  51.8625          E46
# 10          1   4.0  16.7000           G6
# 11          1  58.0  26.5500         C103
# ..        ...   ...      ...          ...
# 871         1  47.0  52.5542          D35
# 872         0  33.0   5.0000  B51 B53 B55
# 879         1  56.0  83.1583          C50
# 887         1  19.0  30.0000          B42
# 889         1  26.0  30.0000         C148
#
# [185 rows x 4 columns]

# %%
f.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# Cabin       0
# dtype: int64

# %%
df=pd.DataFrame([
        [100,90,np.nan,95],
        [30,45,56,np.nan],
        [np.nan,40,80,98]
                ])

# %%
df
# Out:
#        0   1     2     3
# 0  100.0  90   NaN  95.0
# 1   30.0  45  56.0   NaN
# 2    NaN  40  80.0  98.0

# %%
df.isnull().sum()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# dtype: int64

# %%
df.notnull().sum()
# Out:
# 0    2
# 1    3
# 2    2
# 3    2
# dtype: int64

# %%
df1=pd.read_csv("dataset/employees.csv")

# %%
df1.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df1.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
df1.notnull().sum()
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# dtype: int64

# %% [markdown]
# # using fillna,replace,interploate

# %% [markdown]
# # Filling null values with a single value

# %%
df.fillna(0)
# Out:
#        0   1     2     3
# 0  100.0  90   0.0  95.0
# 1   30.0  45  56.0   0.0
# 2    0.0  40  80.0  98.0

# %% [markdown]
# # Code #2: Filling null values with the previous ones

# %%
df.fillna(method="pad")
# Out:
#        0   1     2     3
# 0  100.0  90   NaN  95.0
# 1   30.0  45  56.0  95.0
# 2   30.0  40  80.0  98.0

# %% [markdown]
# # Output:    Code #3: Filling null value with the next ones

# %%
df.fillna(method="bfill")
# Out:
#        0   1     2     3
# 0  100.0  90  56.0  95.0
# 1   30.0  45  56.0  98.0
# 2    NaN  40  80.0  98.0

# %% [markdown]
# # Code #4: Filling null values in CSV File

# %%
df1=pd.read_csv("dataset/employees.csv")

# %%
df1.head(2)
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas   Male  3/31/1996         6:53 AM   61933    4.170
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN

# %%
df2=df1["Gender"].fillna("Non Gender")
df2
# Out:
# 0            Male
# 1            Male
# 2          Female
# 3            Male
# 4            Male
#           ...
# 995    Non Gender
# 996          Male
# 997          Male
# 998          Male
# 999          Male
# Name: Gender, Length: 1000, dtype: object

# %%
df1.replace(np.nan,value=-99)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     -99  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   -99
# ...

# %%
df1.dropna()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
df.dropna(axis=1,how="any")
# Out:
#     1
# 0  90
# 1  45
# 2  40
