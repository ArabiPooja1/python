# %%
import pandas as pd
import numpy as np

# %%
sr1=pd.Series([2,4,3,6,7,8])
sr2=pd.Series([3,6,5,7,8,9],index=[1,2,3,4,5,6])

# %%
sr1
# Out:
# 0    2
# 1    4
# 2    3
# 3    6
# 4    7
# 5    8
# dtype: int64

# %%
sr2
# Out:
# 1    3
# 2    6
# 3    5
# 4    7
# 5    8
# 6    9
# dtype: int64

# %%
sr1+sr2
# Out:
# 0     NaN
# 1     7.0
# 2     9.0
# 3    11.0
# 4    14.0
# 5    16.0
# 6     NaN
# dtype: float64

# %%
sr1*sr2
# Out:
# 0     NaN
# 1    12.0
# 2    18.0
# 3    30.0
# 4    49.0
# 5    64.0
# 6     NaN
# dtype: float64

# %%
sr1-sr2
# Out:
# 0    NaN
# 1    1.0
# 2   -3.0
# 3    1.0
# 4    0.0
# 5    0.0
# 6    NaN
# dtype: float64

# %%
sr1**sr2
# Out:
# 0           NaN
# 1          64.0
# 2         729.0
# 3        7776.0
# 4      823543.0
# 5    16777216.0
# 6           NaN
# dtype: float64

# %%
sr1=pd.Series([2,4,3,6,7,8])
sr2=pd.Series([2,6,5,7,8,9])

# %%
sr1>sr2
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
sr1<sr2
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# dtype: bool

# %%
sr1==sr2
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
np.sqrt(sr1)
# Out:
# 0    1.414214
# 1    2.000000
# 2    1.732051
# 3    2.449490
# 4    2.645751
# 5    2.828427
# dtype: float64

# %%
np.abs(sr1)
# Out:
# 0    2
# 1    4
# 2    3
# 3    6
# 4    7
# 5    8
# dtype: int64

# %%
np.sum(sr1)
# Out:
# 30

# %%
sr1.min()
# Out:
# 2

# %%
sr1.max()
# Out:
# 8

# %%
sr1.argmax()
# Out:
# 5

# %%
sr1.cumsum()
# Out:
# 0     2
# 1     6
# 2     9
# 3    15
# 4    22
# 5    30
# dtype: int64

# %%
sr1.std()
# Out:
# 2.3664319132398464

# %%
sr1.var()
# Out:
# 5.6

# %%
sr1.mean()
# Out:
# 5.0

# %%
a=np.random.randn(10,5)
a
# Out:
# array([[-4.60258435e-01,  4.82972198e-01, -3.67551774e-01,
#         -3.02984729e-01,  4.52251485e-01],
#        [-9.01821802e-01, -6.77702906e-01,  2.25803220e-03,
#          9.44659004e-01, -2.33489396e+00],
#        [-1.97630728e-01,  1.31642751e+00, -6.72944273e-03,
#         -5.57294293e-01, -1.77447909e+00],
#        [ 6.88020974e-01,  4.27210988e-01,  9.46490020e-01,
#          9.23853342e-01, -9.31859973e-01],
#        [ 1.59446813e-02,  1.02446303e+00,  1.68407183e-01,
#         -2.08302504e-01, -9.90091102e-01],
#        [ 1.74168860e-01,  3.39527072e-01, -1.99694244e+00,
#          4.39174173e-01, -3.09861957e-01],
#        [ 8.62465511e-01, -8.04852792e-01,  2.50541467e-01,
#          4.39872384e-01,  2.81468070e-01],
#        [-1.14935307e+00,  1.00764115e+00,  1.00868804e+00,
#         -6.33436296e-01,  4.75702163e-01],
#        [-2.34562356e+00, -6.30060943e-01,  7.19248316e-02,
#          3.68930256e-01,  6.51527729e-01],
# ...

# %%
a=pd.DataFrame(a)
a
# Out:
#           0         1         2         3         4
# 0 -0.460258  0.482972 -0.367552 -0.302985  0.452251
# 1 -0.901822 -0.677703  0.002258  0.944659 -2.334894
# 2 -0.197631  1.316428 -0.006729 -0.557294 -1.774479
# 3  0.688021  0.427211  0.946490  0.923853 -0.931860
# 4  0.015945  1.024463  0.168407 -0.208303 -0.990091
# 5  0.174169  0.339527 -1.996942  0.439174 -0.309862
# 6  0.862466 -0.804853  0.250541  0.439872  0.281468
# 7 -1.149353  1.007641  1.008688 -0.633436  0.475702
# 8 -2.345624 -0.630061  0.071925  0.368930  0.651528
# 9  0.976387 -1.609270  1.670955  0.719904 -0.317250

# %%
a.head()
# Out:
#           0         1         2         3         4
# 0 -0.460258  0.482972 -0.367552 -0.302985  0.452251
# 1 -0.901822 -0.677703  0.002258  0.944659 -2.334894
# 2 -0.197631  1.316428 -0.006729 -0.557294 -1.774479
# 3  0.688021  0.427211  0.946490  0.923853 -0.931860
# 4  0.015945  1.024463  0.168407 -0.208303 -0.990091

# %%
a.head(2)
# Out:
#           0         1         2         3         4
# 0 -0.460258  0.482972 -0.367552 -0.302985  0.452251
# 1 -0.901822 -0.677703  0.002258  0.944659 -2.334894

# %%
a.tail()
# Out:
#           0         1         2         3         4
# 5  0.174169  0.339527 -1.996942  0.439174 -0.309862
# 6  0.862466 -0.804853  0.250541  0.439872  0.281468
# 7 -1.149353  1.007641  1.008688 -0.633436  0.475702
# 8 -2.345624 -0.630061  0.071925  0.368930  0.651528
# 9  0.976387 -1.609270  1.670955  0.719904 -0.317250

# %%
a.tail(3)
# Out:
#           0         1         2         3         4
# 7 -1.149353  1.007641  1.008688 -0.633436  0.475702
# 8 -2.345624 -0.630061  0.071925  0.368930  0.651528
# 9  0.976387 -1.609270  1.670955  0.719904 -0.317250

# %%
a.columns=['A','B','C',"D",'E']
a
# Out:
#           A         B         C         D         E
# 0 -0.460258  0.482972 -0.367552 -0.302985  0.452251
# 1 -0.901822 -0.677703  0.002258  0.944659 -2.334894
# 2 -0.197631  1.316428 -0.006729 -0.557294 -1.774479
# 3  0.688021  0.427211  0.946490  0.923853 -0.931860
# 4  0.015945  1.024463  0.168407 -0.208303 -0.990091
# 5  0.174169  0.339527 -1.996942  0.439174 -0.309862
# 6  0.862466 -0.804853  0.250541  0.439872  0.281468
# 7 -1.149353  1.007641  1.008688 -0.633436  0.475702
# 8 -2.345624 -0.630061  0.071925  0.368930  0.651528
# 9  0.976387 -1.609270  1.670955  0.719904 -0.317250

# %%
cols='A','B','C',"D",'E'.split()

# %%
a.DataFrame=cols
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21648\375743466.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   a.DataFrame=cols

# %%
a
# Out:
#           A         B         C         D         E
# 0 -0.460258  0.482972 -0.367552 -0.302985  0.452251
# 1 -0.901822 -0.677703  0.002258  0.944659 -2.334894
# 2 -0.197631  1.316428 -0.006729 -0.557294 -1.774479
# 3  0.688021  0.427211  0.946490  0.923853 -0.931860
# 4  0.015945  1.024463  0.168407 -0.208303 -0.990091
# 5  0.174169  0.339527 -1.996942  0.439174 -0.309862
# 6  0.862466 -0.804853  0.250541  0.439872  0.281468
# 7 -1.149353  1.007641  1.008688 -0.633436  0.475702
# 8 -2.345624 -0.630061  0.071925  0.368930  0.651528
# 9  0.976387 -1.609270  1.670955  0.719904 -0.317250

# %%
a.head(),a.tail()
# Out:
# (          A         B         C         D         E
#  0 -0.460258  0.482972 -0.367552 -0.302985  0.452251
#  1 -0.901822 -0.677703  0.002258  0.944659 -2.334894
#  2 -0.197631  1.316428 -0.006729 -0.557294 -1.774479
#  3  0.688021  0.427211  0.946490  0.923853 -0.931860
#  4  0.015945  1.024463  0.168407 -0.208303 -0.990091,
#            A         B         C         D         E
#  5  0.174169  0.339527 -1.996942  0.439174 -0.309862
#  6  0.862466 -0.804853  0.250541  0.439872  0.281468
#  7 -1.149353  1.007641  1.008688 -0.633436  0.475702
#  8 -2.345624 -0.630061  0.071925  0.368930  0.651528
#  9  0.976387 -1.609270  1.670955  0.719904 -0.317250)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       10 non-null     float64
#  1   B       10 non-null     float64
#  2   C       10 non-null     float64
#  3   D       10 non-null     float64
#  4   E       10 non-null     float64
# dtypes: float64(5)
# memory usage: 528.0 bytes

# %%
index=pd.date_range("1/1/2022",periods=10)

# %%
index
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
a.set_index(index,inplace=True)

# %%
a
# Out:
#                    A         B         C         D         E
# 2022-01-01 -0.460258  0.482972 -0.367552 -0.302985  0.452251
# 2022-01-02 -0.901822 -0.677703  0.002258  0.944659 -2.334894
# 2022-01-03 -0.197631  1.316428 -0.006729 -0.557294 -1.774479
# 2022-01-04  0.688021  0.427211  0.946490  0.923853 -0.931860
# 2022-01-05  0.015945  1.024463  0.168407 -0.208303 -0.990091
# 2022-01-06  0.174169  0.339527 -1.996942  0.439174 -0.309862
# 2022-01-07  0.862466 -0.804853  0.250541  0.439872  0.281468
# 2022-01-08 -1.149353  1.007641  1.008688 -0.633436  0.475702
# 2022-01-09 -2.345624 -0.630061  0.071925  0.368930  0.651528
# 2022-01-10  0.976387 -1.609270  1.670955  0.719904 -0.317250

# %%
a['A']
# Out:
# 2022-01-01   -0.460258
# 2022-01-02   -0.901822
# 2022-01-03   -0.197631
# 2022-01-04    0.688021
# 2022-01-05    0.015945
# 2022-01-06    0.174169
# 2022-01-07    0.862466
# 2022-01-08   -1.149353
# 2022-01-09   -2.345624
# 2022-01-10    0.976387
# Freq: D, Name: A, dtype: float64

# %%
a[['A']]
# Out:
#                    A
# 2022-01-01 -0.460258
# 2022-01-02 -0.901822
# 2022-01-03 -0.197631
# 2022-01-04  0.688021
# 2022-01-05  0.015945
# 2022-01-06  0.174169
# 2022-01-07  0.862466
# 2022-01-08 -1.149353
# 2022-01-09 -2.345624
# 2022-01-10  0.976387

# %%
a.A
# Out:
# 2022-01-01   -0.460258
# 2022-01-02   -0.901822
# 2022-01-03   -0.197631
# 2022-01-04    0.688021
# 2022-01-05    0.015945
# 2022-01-06    0.174169
# 2022-01-07    0.862466
# 2022-01-08   -1.149353
# 2022-01-09   -2.345624
# 2022-01-10    0.976387
# Freq: D, Name: A, dtype: float64

# %%
a.iloc[0]
# Out:
# A   -0.460258
# B    0.482972
# C   -0.367552
# D   -0.302985
# E    0.452251
# Name: 2022-01-01 00:00:00, dtype: float64

# %%
a.iloc[[0,3,4]]
# Out:
#                    A         B         C         D         E
# 2022-01-01 -0.460258  0.482972 -0.367552 -0.302985  0.452251
# 2022-01-04  0.688021  0.427211  0.946490  0.923853 -0.931860
# 2022-01-05  0.015945  1.024463  0.168407 -0.208303 -0.990091

# %%
a.iloc[:,0]
# Out:
# 2022-01-01   -0.460258
# 2022-01-02   -0.901822
# 2022-01-03   -0.197631
# 2022-01-04    0.688021
# 2022-01-05    0.015945
# 2022-01-06    0.174169
# 2022-01-07    0.862466
# 2022-01-08   -1.149353
# 2022-01-09   -2.345624
# 2022-01-10    0.976387
# Freq: D, Name: A, dtype: float64

# %%
a.iloc[:,0:3]
# Out:
#                    A         B         C
# 2022-01-01 -0.460258  0.482972 -0.367552
# 2022-01-02 -0.901822 -0.677703  0.002258
# 2022-01-03 -0.197631  1.316428 -0.006729
# 2022-01-04  0.688021  0.427211  0.946490
# 2022-01-05  0.015945  1.024463  0.168407
# 2022-01-06  0.174169  0.339527 -1.996942
# 2022-01-07  0.862466 -0.804853  0.250541
# 2022-01-08 -1.149353  1.007641  1.008688
# 2022-01-09 -2.345624 -0.630061  0.071925
# 2022-01-10  0.976387 -1.609270  1.670955

# %%
a.iloc[:,1:2]
# Out:
#                    B
# 2022-01-01  0.482972
# 2022-01-02 -0.677703
# 2022-01-03  1.316428
# 2022-01-04  0.427211
# 2022-01-05  1.024463
# 2022-01-06  0.339527
# 2022-01-07 -0.804853
# 2022-01-08  1.007641
# 2022-01-09 -0.630061
# 2022-01-10 -1.609270

# %%
a.iloc[2:4,3]
# Out:
# 2022-01-03   -0.557294
# 2022-01-04    0.923853
# Freq: D, Name: D, dtype: float64

# %%
a.iloc[2:3,4:5]
# Out:
#                    E
# 2022-01-03 -1.774479

# %% [markdown]
# # creating series

# %%
sr1=pd.Series([2,3,4,5])
sr2=pd.Series([5,6,7,8])
print(sr1)
print(sr2)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64

# %%
sr=pd.Series([2,3,4,5,6],index=["osa","java","SE","python","CN"])
sr
# Out:
# osa       2
# java      3
# SE        4
# python    5
# CN        6
# dtype: int64

# %%
i=["osa","se","java","python","CN","Hardware"]
sr3=pd.Series([2,3,4,5,6,7],index=i)
sr3
# Out:
# osa         2
# se          3
# java        4
# python      5
# CN          6
# Hardware    7
# dtype: int64

# %%
sr4=pd.Series({
    "osa":23,
    "java":34,
    "SE":12,
    "python":2,
    "CN":100,
    "hardware":99
})
sr4
# Out:
# osa          23
# java         34
# SE           12
# python        2
# CN          100
# hardware     99
# dtype: int64

# %%
sr5=pd.DataFrame([
    ["Abi",34],
    ["Akash",45],
    ["Asya",23],
    ["prachi",45]
],index=["osa","java","SE","python"],columns=["Name","Marks"])
sr5
# Out:
#           Name  Marks
# osa        Abi     34
# java     Akash     45
# SE        Asya     23
# python  prachi     45

# %%
sr6=pd.DataFrame({
    "Name":["Abi","Akash","Asya","prachi"],
    "marks":[4,56,78,99]
},index=["osa","java","se","python"])

# %%
sr6
# Out:
#           Name  marks
# osa        Abi      4
# java     Akash     56
# se        Asya     78
# python  prachi     99

# %%
sr1=pd.Series(["Abi","Akash","Asya","prachi"])
sr2=pd.Series([1,2,3,4])
pd.DataFrame({
    "Name":sr1,
    "marks":sr2
})
# Out:
#      Name  marks
# 0     Abi      1
# 1   Akash      2
# 2    Asya      3
# 3  prachi      4

# %%
i=["karnataka","maharastra","kerala"]
sr1=pd.Series(["bendaluru","mumbai","tiruvanatapuram"],index=i)
sr2=pd.Series([10,20,30],index=i)
df=pd.DataFrame({"capital":sr1,"population":sr2})

# %%
df
# Out:
#                     capital  population
# karnataka         bendaluru          10
# maharastra           mumbai          20
# kerala      tiruvanatapuram          30

# %%
df.append(pd.DataFrame([["Gandinagar",45]],columns=["capital","population"],index=["gujarath"]))
#print(df.append(pd.DataFrame([['8.9','Channai'],['12.54','Hydrabad']],index=['Tamil Nadu','Andra Pradesh'],columns=['Population','Capital'])))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21648\2880705159.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(pd.DataFrame([["Gandinagar",45]],columns=["capital","population"],index=["gujarath"]))
#                     capital  population
# karnataka         bendaluru          10
# maharastra           mumbai          20
# kerala      tiruvanatapuram          30
# gujarath         Gandinagar          45

# %%
a=pd.DataFrame([
    ["bendaluru",10],
    ["mumbai",20],
    ["tiruvanatapuram",30],
    ["Gandinagar",45]
],index=["karnataka","maharastra","kerala","gujarath"],columns=["capital","population"])

# %%
a
# Out:
#                     capital  population
# karnataka         bendaluru          10
# maharastra           mumbai          20
# kerala      tiruvanatapuram          30
# gujarath         Gandinagar          45

# %%
a.append(pd.DataFrame([["hariyana",23]],columns=["capital","population"],index=["panjab"]))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21648\345929433.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a.append(pd.DataFrame([["hariyana",23]],columns=["capital","population"],index=["panjab"]))
#                     capital  population
# karnataka         bendaluru          10
# maharastra           mumbai          20
# kerala      tiruvanatapuram          30
# gujarath         Gandinagar          45
# panjab             hariyana          23

# %%
import pandas as pd
a=pd.Series([1,5,8,9,6,7])
print(a)
# Out:
# 0    1
# 1    5
# 2    8
# 3    9
# 4    6
# 5    7
# dtype: int64

# %%
a.mean()
# Out:
# 6.0

# %%
a.sum()
# Out:
# 36

# %%
a.max()
# Out:
# 9

# %%
a.min()
# Out:
# 1

# %%
a.count()
# Out:
# 6

# %%
a.mean()
# Out:
# 6.0

# %%
a.std()
# Out:
# 2.8284271247461903

# %%
a.abs()
# Out:
# 0    1
# 1    5
# 2    8
# 3    9
# 4    6
# 5    7
# dtype: int64

# %%
a.argmax()
# Out:
# 3

# %%
a.argmin()
# Out:
# 0

# %%
a.cumsum()
# Out:
# 0     1
# 1     6
# 2    14
# 3    23
# 4    29
# 5    36
# dtype: int64

# %% [markdown]
# # Groupby function

# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv("dataset/titanic.csv")

# %%
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
a.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
a.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
a.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
a.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
a.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
a.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
a[['Age','Cabin']].isnull().sum()
# Out:
# Age      177
# Cabin    687
# dtype: int64

# %%
a.drop(columns=["Name","PassengerId","Cabin","Ticket"],axis=1,inplace=True)

# %%
a
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
a.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
a['Age'].isnull().sum()
# Out:
# 177

# %%
a=a.fillna(method="ffill")

# %%
a.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# # Using group by calse

# %%
a.groupby('Survived')['Survived'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
a.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
a.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
a.groupby('Embarked')['Embarked'].count()
# Out:
# Embarked
# C    169
# Q     78
# S    644
# Name: Embarked, dtype: int64

# %%
a.groupby('Sex')['Survived'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
a.groupby('Pclass')['Survived'].agg(["sum","count"])
# Out:
#         sum  count
# Pclass
# 1       136    216
# 2        87    184
# 3       119    491

# %%
a.groupby(['Pclass','Sex','Survived'])['Survived'].count()
# Out:
# Pclass  Sex     Survived
# 1       female  0             3
#                 1            91
#         male    0            77
#                 1            45
# 2       female  0             6
#                 1            70
#         male    0            91
#                 1            17
# 3       female  0            72
#                 1            72
#         male    0           300
#                 1            47
# Name: Survived, dtype: int64

# %%
a.groupby('Pclass')['Survived'].sum()/a.groupby('Pclass')['Survived'].count()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
a=pd.read_excel("dataset/SaleData.xlsx")

# %%
a.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0

# %%
a.describe()
# Out:
#             Units   Unit_price       Sale_amt
# count   45.000000    45.000000      45.000000
# mean    54.083333   583.313889   30578.761111
# std     45.096676   444.806622   32227.534943
# min      2.000000    58.500000     250.000000
# 25%     28.000000   225.000000    4329.000000
# 50%     53.000000   500.000000   17100.000000
# 75%     75.000000  1198.000000   43128.000000
# max    278.000000  1198.000000  113810.000000

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     datetime64[ns]
#  1   Region      43 non-null     object
#  2   Manager     43 non-null     object
#  3   SalesMan    43 non-null     object
#  4   Item        43 non-null     object
#  5   Units       45 non-null     float64
#  6   Unit_price  45 non-null     float64
#  7   Sale_amt    45 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 2.9+ KB

# %%
a.isnull().sum()
# Out:
# OrderDate     2
# Region        2
# Manager       2
# SalesMan      2
# Item          2
# Units         0
# Unit_price    0
# Sale_amt      0
# dtype: int64

# %%
a=a.dropna()

# %%
a.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0

# %%
a.columns
# Out:
# Index(['OrderDate', 'Region', 'Manager', 'SalesMan', 'Item', 'Units',
#        'Unit_price', 'Sale_amt'],
#       dtype='object')

# %%
b=a.groupby(['Region','Manager'])['Sale_amt'].sum()
print(b)
# Out:
# Region   Manager
# Central  Douglas    124016.0
#          Hermann    365108.5
#          Martha     199690.0
#          Timothy    140955.0
# East     Douglas     48204.0
#          Martha     272803.0
# West     Douglas     66836.0
#          Timothy     88063.0
# Name: Sale_amt, dtype: float64

# %%
a.groupby(["Region","Manager","SalesMan"])["Sale_amt"].sum()
# Out:
# Region   Manager  SalesMan
# Central  Douglas  John         124016.0
#          Hermann  Luis         206373.0
#                   Shelli        33698.0
#                   Sigal        125037.5
#          Martha   Steven       199690.0
#          Timothy  David        140955.0
# East     Douglas  Karen         48204.0
#          Martha   Alexander    236703.0
#                   Diana         36100.0
# West     Douglas  Michael       66836.0
#          Timothy  Stephen       88063.0
# Name: Sale_amt, dtype: float64

# %%
a.groupby(["Item"])['Units'].sum()
# Out:
# Item
# Cell Phone      278.0
# Desk             10.0
# Home Theater    722.0
# Television      716.0
# Video Games     395.0
# Name: Units, dtype: float64

# %%
a.groupby("Region")["Sale_amt"].sum()
# Out:
# Region
# Central    829769.5
# East       321007.0
# West       154899.0
# Name: Sale_amt, dtype: float64

# %%
a.groupby(['Region','Item'])['Units'].sum()
# Out:
# Region   Item
# Central  Cell Phone       27.0
#          Desk              7.0
#          Home Theater    424.0
#          Television      498.0
#          Video Games     243.0
# East     Cell Phone      175.0
#          Home Theater    234.0
#          Television      130.0
#          Video Games     152.0
# West     Cell Phone       76.0
#          Desk              3.0
#          Home Theater     64.0
#          Television       88.0
# Name: Units, dtype: float64

# %%
a.groupby("Manager")["Sale_amt"].agg(["mean","count"])
# Out:
#                  mean  count
# Manager
# Douglas  29882.000000      8
# Hermann  30425.708333     12
# Martha   33749.500000     14
# Timothy  25446.444444      9

# %%
a.groupby(["Manager","SalesMan"])["Sale_amt"].sum()
# Out:
# Manager  SalesMan
# Douglas  John         124016.0
#          Karen         48204.0
#          Michael       66836.0
# Hermann  Luis         206373.0
#          Shelli        33698.0
#          Sigal        125037.5
# Martha   Alexander    236703.0
#          Diana         36100.0
#          Steven       199690.0
# Timothy  David        140955.0
#          Stephen       88063.0
# Name: Sale_amt, dtype: float64

# %%
a.columns
# Out:
# Index(['OrderDate', 'Region', 'Manager', 'SalesMan', 'Item', 'Units',
#        'Unit_price', 'Sale_amt'],
#       dtype='object')

# %%
a.groupby("Item")["Sale_amt"].max()
# Out:
# Item
# Cell Phone       21600.0
# Desk               625.0
# Home Theater     47000.0
# Television      113810.0
# Video Games       5616.0
# Name: Sale_amt, dtype: float64

# %%
a.groupby("Item")["Sale_amt"].min()
# Out:
# Item
# Cell Phone      3375.0
# Desk             250.0
# Home Theater    2000.0
# Television      8386.0
# Video Games      936.0
# Name: Sale_amt, dtype: float64

# %%
a.groupby("Item")["Sale_amt"].agg(["min","max"])
# Out:
#                  min       max
# Item
# Cell Phone    3375.0   21600.0
# Desk           250.0     625.0
# Home Theater  2000.0   47000.0
# Television    8386.0  113810.0
# Video Games    936.0    5616.0

# %%
df=pd.DataFrame([
    ["Aryan","Singh","full-time employee","Administation",2,20000],
    ["Rohan","Agarwal","Inter","Technical",3,5000],
    ["Riya","Shah","full-time employee","Administation",5,10000],
    ["Yash","Bhatia","part-time employee","Technical",7,10000],
    ["Siddhant","Khanna","full-time employee","Management",6,20000]
],columns=["First Name","Last NAme","Type","Department","YoE","Salary"])

# %%
df.groupby(['Type']).sum()
# Out:
#                     YoE  Salary
# Type
# Inter                 3    5000
# full-time employee   13   50000
# part-time employee    7   10000

# %%
df.groupby("Type")["Salary"].sum()
# Out:
# Type
# Inter                  5000
# full-time employee    50000
# part-time employee    10000
# Name: Salary, dtype: int64

# %%
df.groupby(["Type","Department"])["Salary"].sum()
# Out:
# Type                Department
# Inter               Technical         5000
# full-time employee  Administation    30000
#                     Management       20000
# part-time employee  Technical        10000
# Name: Salary, dtype: int64

# %% [markdown]
# # Pivot Tabel

# %%
b=pd.read_csv("dataset/titanic.csv")

# %%
b.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
b.describe()
# Out:
#            Units   Unit_price       Sale_amt
# count  43.000000    43.000000      43.000000
# mean   49.325581   581.011628   30364.546512
# std    30.078248   442.285830   32424.588323
# min     2.000000    58.500000     250.000000
# 25%    27.500000   225.000000    3978.000000
# 50%    53.000000   500.000000   17100.000000
# 75%    74.500000  1198.000000   42529.000000
# max    96.000000  1198.000000  113810.000000

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     datetime64[ns]
#  1   Region      43 non-null     object
#  2   Manager     43 non-null     object
#  3   SalesMan    43 non-null     object
#  4   Item        43 non-null     object
#  5   Units       43 non-null     float64
#  6   Unit_price  43 non-null     float64
#  7   Sale_amt    43 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 3.0+ KB

# %%
b.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
b.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
b.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
b["Age"].isnull().sum()
# Out:
# 177

# %%
b=b.fillna(method="ffill")
b.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   C85        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  C123        S

# %%
b.pivot_table(values=["Cabin"],index=["Sex"],columns=["Pclass"],aggfunc=["count"])
# Out:
#        count
#        Cabin
# Pclass     1    2    3
# Sex
# female    94   76  144
# male     122  108  346

# %%
b.pivot_table(values=['Survived'],index=["Pclass","Sex"],aggfunc=["sum"])
# Out:
#                    sum
#               Survived
# Pclass Sex
# 1      female       91
#        male         45
# 2      female       70
#        male         17
# 3      female       72
#        male         47

# %%
b.pivot_table(values=["Survived"],index=["Pclass"],aggfunc=["sum"])
# Out:
#             sum
#        Survived
# Pclass
# 1           136
# 2            87
# 3           119

# %%
b.pivot_table(values=["Survived"],index=['Pclass'],aggfunc=["count"])
# Out:
#           count
#        Survived
# Pclass
# 1           216
# 2           184
# 3           491

# %%
b.pivot_table(values=["Survived"],index=["Sex"],columns=["Pclass"])
# Out:
#         Survived
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
b.pivot_table(values=["Survived"],index=["Sex"],aggfunc=["sum"])
# Out:
#             sum
#        Survived
# Sex
# female      233
# male        109

# %%
b.pivot_table(values=["Survived"],index=["Sex","Age","Pclass"],aggfunc=["mean"])
# Out:
#                         mean
#                     Survived
# Sex    Age   Pclass
# female 0.75  3           1.0
#        0.92  1           1.0
#        1.00  3           1.0
#        2.00  1           0.0
#              2           1.0
# ...                      ...
# male   70.00 2           0.0
#        70.50 3           0.0
#        71.00 1           0.0
#        74.00 3           0.0
#        80.00 1           1.0
#
# [307 rows x 1 columns]

# %%
b.pivot_table(values=["Survived"],index=["Sex","Age"],columns=["Pclass"],aggfunc=["count"])
# Out:
#                 count
#              Survived
# Pclass              1    2    3
# Sex    Age
# female 0.75       NaN  NaN  2.0
#        0.92       1.0  NaN  NaN
#        1.00       NaN  NaN  2.0
#        2.00       1.0  1.0  4.0
#        3.00       1.0  1.0  1.0
# ...               ...  ...  ...
# male   70.00      1.0  1.0  NaN
#        70.50      NaN  NaN  1.0
#        71.00      2.0  NaN  NaN
#        74.00      NaN  NaN  1.0
#        80.00      1.0  NaN  NaN
#
# [149 rows x 3 columns]

# %% [markdown]
# # Second PDF

# %%
b.pivot_table(values=("Survived"),index=["Pclass","Sex"],aggfunc="sum")
# Out:
#                Survived
# Pclass Sex
# 1      female        91
#        male          45
# 2      female        70
#        male          17
# 3      female        72
#        male          47

# %%
b.pivot_table(values=["Survived"],index=["Sex"],columns=["Pclass"],aggfunc="sum")
# Out:
#        Survived
# Pclass        1   2   3
# Sex
# female       91  70  72
# male         45  17  47

# %%
b.pivot_table(values=["Survived"],index=["Sex"],columns=["Pclass"],aggfunc="count")
# Out:
#        Survived
# Pclass        1    2    3
# Sex
# female       94   76  144
# male        122  108  347

# %%
b.pivot_table(values=["Survived"],index=["Sex"],columns=['Pclass'])
# Out:
#         Survived
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
b.pivot_table(values="Survived",index="Sex",aggfunc="sum")
# Out:
#         Survived
# Sex
# female       233
# male         109

# %%
b.pivot_table(values="Survived",index=["Sex","Age"],columns=["Pclass"])
# Out:
# Pclass          1    2     3
# Sex    Age
# female 0.75   NaN  NaN  1.00
#        0.92   1.0  NaN   NaN
#        1.00   NaN  NaN  1.00
#        2.00   0.0  1.0  0.25
#        3.00   1.0  1.0  0.00
# ...           ...  ...   ...
# male   70.00  0.0  0.0   NaN
#        70.50  NaN  NaN  0.00
#        71.00  0.0  NaN   NaN
#        74.00  NaN  NaN  0.00
#        80.00  1.0  NaN   NaN
#
# [149 rows x 3 columns]

# %%
df=pd.DataFrame([
    ["Aryan","Singh","full-time employee","Administation",2,20000],
    ["Rohan","Agarwal","Inter","Technical",3,5000],
    ["Riya","Shah","full-time employee","Administation",5,10000],
    ["Yash","Bhatia","part-time employee","Technical",7,10000],
    ["Siddhant","Khanna","full-time employee","Management",6,20000]
],columns=["First Name","Last NAme","Type","Department","YoE","Salary"])

# %%
df
# Out:
#   First Name Last NAme                Type     Department  YoE  Salary
# 0      Aryan     Singh  full-time employee  Administation    2   20000
# 1      Rohan   Agarwal               Inter      Technical    3    5000
# 2       Riya      Shah  full-time employee  Administation    5   10000
# 3       Yash    Bhatia  part-time employee      Technical    7   10000
# 4   Siddhant    Khanna  full-time employee     Management    6   20000

# %%
df.pivot_table(values=["Salary"],index=["Type"],columns=["Department"])
# Out:
#                           Salary
# Department         Administation Management Technical
# Type
# Inter                        NaN        NaN    5000.0
# full-time employee       15000.0    20000.0       NaN
# part-time employee           NaN        NaN   10000.0

# %%
df.pivot_table(values=["Salary"],index=["Type"],aggfunc=["sum","mean","count"])
# Out:
#                       sum          mean  count
#                    Salary        Salary Salary
# Type
# Inter                5000   5000.000000      1
# full-time employee  50000  16666.666667      3
# part-time employee  10000  10000.000000      1

# %%
df1=pd.read_excel("dataset/SaleData.xlsx")

# %%
df1.head(2)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0

# %%
df1.describe()
# Out:
#             Units   Unit_price       Sale_amt
# count   45.000000    45.000000      45.000000
# mean    54.083333   583.313889   30578.761111
# std     45.096676   444.806622   32227.534943
# min      2.000000    58.500000     250.000000
# 25%     28.000000   225.000000    4329.000000
# 50%     53.000000   500.000000   17100.000000
# 75%     75.000000  1198.000000   43128.000000
# max    278.000000  1198.000000  113810.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     datetime64[ns]
#  1   Region      43 non-null     object
#  2   Manager     43 non-null     object
#  3   SalesMan    43 non-null     object
#  4   Item        43 non-null     object
#  5   Units       45 non-null     float64
#  6   Unit_price  45 non-null     float64
#  7   Sale_amt    45 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 2.9+ KB

# %%
df1.isnull().sum()
# Out:
# OrderDate     2
# Region        2
# Manager       2
# SalesMan      2
# Item          2
# Units         0
# Unit_price    0
# Sale_amt      0
# dtype: int64

# %%
df1.count().sum()
# Out:
# 350

# %%
df1=df1.dropna()
df1.head(2)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0

# %%
df1.isnull().sum()
# Out:
# OrderDate     0
# Region        0
# Manager       0
# SalesMan      0
# Item          0
# Units         0
# Unit_price    0
# Sale_amt      0
# dtype: int64

# %%
df1.count().sum()
# Out:
# 344

# %%
df1.pivot_table(index=["Region","Manager","Units"])
# Out:
#                        Sale_amt  Unit_price
# Region  Manager Units
# Central Douglas 2.0       250.0      125.00
#                 67.0    80266.0     1198.00
#                 87.0    43500.0      500.00
#         Hermann 5.0       625.0      125.00
#                 11.0     5500.0      500.00
#                 28.0    14000.0      500.00
#                 36.0    43128.0     1198.00
#                 42.0     2457.0       58.50
#                 50.0    13962.5      279.25
#                 55.0     3217.5       58.50
#                 90.0   107820.0     1198.00
#                 94.0    47000.0      500.00
#                 96.0     5616.0       58.50
#         Martha  14.0    16772.0     1198.00
#                 28.0    14000.0      500.00
#                 66.0    79068.0     1198.00
#                 75.0    89850.0     1198.00
#         Timothy 7.0      8386.0     1198.00
#                 27.0     6075.0      225.00
#                 46.0    23000.0      500.00
# ...

# %%
df1.pivot_table(values=["Sale_amt"],index=["Region","Manager"],aggfunc=["sum"])
# Out:
#                       sum
#                  Sale_amt
# Region  Manager
# Central Douglas  124016.0
#         Hermann  365108.5
#         Martha   199690.0
#         Timothy  140955.0
# East    Douglas   48204.0
#         Martha   272803.0
# West    Douglas   66836.0
#         Timothy   88063.0

# %%
a.pivot_table(values=["Sale_amt"],index=["Region","Manager","SalesMan"],aggfunc="sum")
# Out:
#                            Sale_amt
# Region  Manager SalesMan
# Central Douglas John       124016.0
#         Hermann Luis       206373.0
#                 Shelli      33698.0
#                 Sigal      125037.5
#         Martha  Steven     199690.0
#         Timothy David      140955.0
# East    Douglas Karen       48204.0
#         Martha  Alexander  236703.0
#                 Diana       36100.0
# West    Douglas Michael     66836.0
#         Timothy Stephen     88063.0

# %%
df1.pivot_table(values="Units",index="Item",aggfunc="sum")
# Out:
#               Units
# Item
# Cell Phone    278.0
# Desk           10.0
# Home Theater  722.0
# Television    716.0
# Video Games   395.0

# %%
df1.pivot_table(values="Sale_amt",index="Region",aggfunc="sum")
# Out:
#          Sale_amt
# Region
# Central  829769.5
# East     321007.0
# West     154899.0

# %%
df1.pivot_table(values="Units",index=["Region","Item"],aggfunc="sum")
# Out:
#                       Units
# Region  Item
# Central Cell Phone     27.0
#         Desk            7.0
#         Home Theater  424.0
#         Television    498.0
#         Video Games   243.0
# East    Cell Phone    175.0
#         Home Theater  234.0
#         Television    130.0
#         Video Games   152.0
# West    Cell Phone     76.0
#         Desk            3.0
#         Home Theater   64.0
#         Television     88.0

# %%
df1.columns
# Out:
# Index(['OrderDate', 'Region', 'Manager', 'SalesMan', 'Item', 'Units',
#        'Unit_price', 'Sale_amt'],
#       dtype='object')

# %%
df1.pivot_table(index=["Manager","SalesMan"],values=["Sale_amt"],aggfunc=["mean","count","sum"])
# Out:
#                            mean    count       sum
#                        Sale_amt Sale_amt  Sale_amt
# Manager SalesMan
# Douglas John       41338.666667        3  124016.0
#         Karen      16068.000000        3   48204.0
#         Michael    33418.000000        2   66836.0
# Hermann Luis       41274.600000        5  206373.0
#         Shelli      8424.500000        4   33698.0
#         Sigal      41679.166667        3  125037.5
# Martha  Alexander  29587.875000        8  236703.0
#         Diana      18050.000000        2   36100.0
#         Steven     49922.500000        4  199690.0
# Timothy David      28191.000000        5  140955.0
#         Stephen    22015.750000        4   88063.0

# %% [markdown]
# # Infos spring board excercise

# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_csv("dataset/rainfall1627650742214.csv")
a.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# ...

# %%
a.isnull().sum()
# no any missing values
# Out:
# STATE_UT_NAME    0
# DISTRICT         0
# JAN              0
# FEB              0
# MAR              0
# APR              0
# MAY              0
# JUN              0
# JUL              0
# AUG              0
# SEP              0
# OCT              0
# NOV              0
# DEC              0
# ANNUAL           0
# Jan-Feb          0
# Mar-May          0
# Jun-Sep          0
# Oct-Dec          0
# dtype: int64

# %%
a[["DISTRICT",'ANNUAL']].max()
# Out:
# DISTRICT    ZUNHEBOTO
# ANNUAL         7229.3
# dtype: object

# %%
a[['DISTRICT','ANNUAL']].sort_values(by=['ANNUAL'],ascending=False).head(1)
# Out:
#       DISTRICT  ANNUAL
# 55  TAMENGLONG  7229.3

# %%
a[['DISTRICT',"ANNUAL"]].sort_values(["ANNUAL"],ascending=False).head(5)
# Out:
#           DISTRICT  ANNUAL
# 55      TAMENGLONG  7229.3
# 47   JAINTIA HILLS  6379.9
# 46   EAST KHASI HI  6166.1
# 12     UPPER SIANG  4402.1
# 598          UDUPI  4306.0

# %%
a.drop(columns=["Jan-Feb","Mar-May","Jun-Sep","Oct-Dec"],inplace=True)

# %%
a
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
a.pivot_table(values=["STATE_UT_NAME"],index=["JAN",'FEB','MAR','APR','MAY','JUN','JUL','AUG','OCT','NOV','DEC'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14292\1755495916.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   a.pivot_table(values=["STATE_UT_NAME"],index=["JAN",'FEB','MAR','APR','MAY','JUN','JUL','AUG','OCT','NOV','DEC'])
# Empty DataFrame
# Columns: []
# ...

# %%
a.pivot_table(index=["STATE_UT_NAME"],values=["DISTRICT"],aggfunc='count')
# Out:
#                              DISTRICT
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS         3
# ANDHRA PRADESH                     23
# ARUNACHAL PRADESH                  16
# ASSAM                              27
# BIHAR                              38
# CHANDIGARH                          1
# CHATISGARH                         18
# DADAR NAGAR HAVELI                  1
# DAMAN AND DUI                       2
# DELHI                               9
# GOA                                 2
# GUJARAT                            26
# HARYANA                            21
# HIMACHAL                           12
# JAMMU AND KASHMIR                  22
# JHARKHAND                          24
# KARNATAKA                          30
# KERALA                             14
# LAKSHADWEEP                         1
# MADHYA PRADESH                     50
# MAHARASHTRA                        35
# MANIPUR                             9
# MEGHALAYA                           7
# ...

# %%
a.pivot_table(values=['DISTRICT',"MAY"],index=['STATE_UT_NAME'],aggfunc="max")
# Out:
#                                    DISTRICT    MAY
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN  374.4
# ANDHRA PRADESH                WEST GODAVARI   96.6
# ARUNACHAL PRADESH                WEST SIANG  453.0
# ASSAM                         UDALGURI(DARA  604.0
# BIHAR                        WEST CHAMPARAN  155.7
# CHANDIGARH                       CHANDIGARH   30.1
# CHATISGARH                          SURGUJA   38.6
# DADAR NAGAR HAVELI                      DNH    7.4
# DAMAN AND DUI                           DIU    7.4
# DELHI                            WEST DELHI   19.3
# GOA                               SOUTH GOA   94.3
# GUJARAT                              VALSAD   12.5
# HARYANA                         YAMUNANAGAR   27.9
# HIMACHAL                                UNA   91.7
# JAMMU AND KASHMIR                  UDHAMPUR  111.4
# JHARKHAND                    WEST SINGHBHUM   86.1
# KARNATAKA                            YADGIR  193.8
# ...
