# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_csv("dataset/student1.csv")

# %%
a
# Out:
#         Reg_no                                  Name
# 0   393CS21707                       VARSHA GALAGALI
# 1   393CS20001              ABHINAV PRASANNA NAIKODI
# 2   393CS20001              ABHINAV PRASANNA NAIKODI
# 3   393CS20002                          AKASH TORAVI
# 4   393CS21702              BIRADAR GURURAJ SIDHARUD
# 5   393CS20005                DUGIWADE PRACHI SANJAY
# 6   393CS21703                   GURUNATH DESHAPANDE
# 7   393CS20006           HARSHAD MAHAMMADSAB WALIKAR
# 8   393CS20007                    IRAMNAAZ JAMKHANDI
# 9   393CS20001              ABHINAV PRASANNA NAIKODI
# 10  393CS20008                   JAHID ALI BALABATTI
# 11  393CS20009                KRISHNA MAHADEV JADHAV
# 12  393CS20010                        LAXMI NAVALAGI
# 13  393CS20011                      MAIBOOBSAB NADAF
# 14  393CS21704                  MANJU SHIVAJI CHAVAN
# 15  393CS20012                  MISBA BUDANSAB MOMIN
# 16  393CS20013                   MODI AVADOOT MAHESH
# ...

# %% [markdown]
# # checking who much duplicated values are there

# %%
a.duplicated().sum()
# Out:
# 14

# %% [markdown]
# # now list the all duplicated value

# %%
a.loc[a.duplicated(),:]
# Out:
#         Reg_no                      Name
# 2   393CS20001  ABHINAV PRASANNA NAIKODI
# 9   393CS20001  ABHINAV PRASANNA NAIKODI
# 32  393CS21707           VARSHA GALAGALI
# 33  393CS20018                NEHA PATIL
# 39  393CS17018            RAHUL BADAKURI
# 40  393CS21702  BIRADAR GURURAJ SIDHARUD
# 41  393CS21703       GURUNATH DESHAPANDE
# 42  393CS21704      MANJU SHIVAJI CHAVAN
# 43  393CS21706      SNEHA ASHOK DODAMANI
# 44  393CS21707           VARSHA GALAGALI
# 45  393CS20008       JAHID ALI BALABATTI
# 46  393CS21706      SNEHA ASHOK DODAMANI
# 47  393CS20028            SPURTI S PATIL
# 48  393CS20030             UMARBIN PATIL

# %% [markdown]
# # Now removing the duplicated value

# %%
a.drop_duplicates()
# Out:
#         Reg_no                                  Name
# 0   393CS21707                       VARSHA GALAGALI
# 1   393CS20001              ABHINAV PRASANNA NAIKODI
# 3   393CS20002                          AKASH TORAVI
# 4   393CS21702              BIRADAR GURURAJ SIDHARUD
# 5   393CS20005                DUGIWADE PRACHI SANJAY
# 6   393CS21703                   GURUNATH DESHAPANDE
# 7   393CS20006           HARSHAD MAHAMMADSAB WALIKAR
# 8   393CS20007                    IRAMNAAZ JAMKHANDI
# 10  393CS20008                   JAHID ALI BALABATTI
# 11  393CS20009                KRISHNA MAHADEV JADHAV
# 12  393CS20010                        LAXMI NAVALAGI
# 13  393CS20011                      MAIBOOBSAB NADAF
# 14  393CS21704                  MANJU SHIVAJI CHAVAN
# 15  393CS20012                  MISBA BUDANSAB MOMIN
# 16  393CS20013                   MODI AVADOOT MAHESH
# 17  393CS20015                     NADAF NIHAL NASIM
# 18  393CS20016                    NANDINI NITIN MODI
# ...

# %% [markdown]
# # Using titanic file

# %%
b=pd.read_csv("dataset/titanic.csv")

# %%
b.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
b.duplicated().sum()
# Out:
# 0

# %%
c=b.drop_duplicates()
c.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
b.duplicated().sum()
# Out:
# 0
