# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("dataset/student1.csv")

# %%
a
# Out:
#         Reg_no                                  Name
# 0   393CS21707                       VARSHA GALAGALI
# 1   393CS20001              ABHINAV PRASANNA NAIKODI
# 2   393CS20001              ABHINAV PRASANNA NAIKODI
# 3   393CS20002                          AKASH TORAVI
# 4   393CS21702              BIRADAR GURURAJ SIDHARUD
# 5   393CS20005                DUGIWADE PRACHI SANJAY
# 6   393CS21703                   GURUNATH DESHAPANDE
# 7   393CS20006           HARSHAD MAHAMMADSAB WALIKAR
# 8   393CS20007                    IRAMNAAZ JAMKHANDI
# 9   393CS20001              ABHINAV PRASANNA NAIKODI
# 10  393CS20008                   JAHID ALI BALABATTI
# 11  393CS20009                KRISHNA MAHADEV JADHAV
# 12  393CS20010                        LAXMI NAVALAGI
# 13  393CS20011                      MAIBOOBSAB NADAF
# 14  393CS21704                  MANJU SHIVAJI CHAVAN
# 15  393CS20012                  MISBA BUDANSAB MOMIN
# 16  393CS20013                   MODI AVADOOT MAHESH
# ...

# %%
b=pd.read_csv("dataset/marks1.csv")

# %%
b
# Out:
#     OSA  CN
# 0    44  45
# 1    97  47
# 2    97  47
# 3    97  52
# 4    75  21
# 5    11  23
# 6    87  92
# 7    45  78
# 8    97  17
# 9    97  47
# 10   23  45
# 11   87  65
# 12   61  39
# 13   33  39
# 14   53  44
# 15   56  62
# 16   22  65
# 17   45  20
# 18   25  15
# 19   90  74
# 20   31  94
# 21   93   3
# 22   41  89
# 23   32  57
# 24   90  91
# 25   76  72
# 26   17  30
# 27   58  49
# 28    4  24
# 29   86  70
# 30   24  87
# 31   20  11
# 32   37  58
# 33   31  94
# 34    7  31
# 35   95  77
# 36   61  84
# 37   88  83
# 38   76  31
# 39    7  31
# 40   77  70
# 41   43  27
# 42   10  14
# 43   90  22
# 44   44  45
# 45   23  45
# 46    4  24
# 47   86  70
# 48   20  11

# %%
df=pd.concat([a,b],axis=1)

# %%
df
# Out:
#         Reg_no                                  Name  OSA  CN
# 0   393CS21707                       VARSHA GALAGALI   44  45
# 1   393CS20001              ABHINAV PRASANNA NAIKODI   97  47
# 2   393CS20001              ABHINAV PRASANNA NAIKODI   97  47
# 3   393CS20002                          AKASH TORAVI   97  52
# 4   393CS21702              BIRADAR GURURAJ SIDHARUD   75  21
# 5   393CS20005                DUGIWADE PRACHI SANJAY   11  23
# 6   393CS21703                   GURUNATH DESHAPANDE   87  92
# 7   393CS20006           HARSHAD MAHAMMADSAB WALIKAR   45  78
# 8   393CS20007                    IRAMNAAZ JAMKHANDI   97  17
# 9   393CS20001              ABHINAV PRASANNA NAIKODI   97  47
# 10  393CS20008                   JAHID ALI BALABATTI   23  45
# 11  393CS20009                KRISHNA MAHADEV JADHAV   87  65
# 12  393CS20010                        LAXMI NAVALAGI   61  39
# 13  393CS20011                      MAIBOOBSAB NADAF   33  39
# ...

# %% [markdown]
# # Adding the attribute

# %%
df['total']=b['OSA']+b["CN"]

# %%
df
# Out:
#         Reg_no                                  Name  OSA  CN  total
# 0   393CS21707                       VARSHA GALAGALI   44  45     89
# 1   393CS20001              ABHINAV PRASANNA NAIKODI   97  47    144
# 2   393CS20001              ABHINAV PRASANNA NAIKODI   97  47    144
# 3   393CS20002                          AKASH TORAVI   97  52    149
# 4   393CS21702              BIRADAR GURURAJ SIDHARUD   75  21     96
# 5   393CS20005                DUGIWADE PRACHI SANJAY   11  23     34
# 6   393CS21703                   GURUNATH DESHAPANDE   87  92    179
# 7   393CS20006           HARSHAD MAHAMMADSAB WALIKAR   45  78    123
# 8   393CS20007                    IRAMNAAZ JAMKHANDI   97  17    114
# 9   393CS20001              ABHINAV PRASANNA NAIKODI   97  47    144
# 10  393CS20008                   JAHID ALI BALABATTI   23  45     68
# 11  393CS20009                KRISHNA MAHADEV JADHAV   87  65    152
# 12  393CS20010                        LAXMI NAVALAGI   61  39    100
# ...

# %%
df['percentage']=df['total']/200*100

# %%
df1=pd.DataFrame([
    ['393CS2002',"Rahul",34,56,134,67.5]
],columns=["Reg_no","Name","OSA","CN","total","percentage"])

# %%
ans=df.append(df1)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19800\3729128217.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ans=df.append(df1)

# %%
ans.isna().sum()
# Out:
# Reg_no        0
# Name          0
# OSA           0
# CN            0
# total         0
# percentage    0
# dtype: int64

# %%
ans
# Out:
#         Reg_no                                  Name  OSA  CN  total  \
# 0   393CS21707                       VARSHA GALAGALI   44  45     89
# 1   393CS20001              ABHINAV PRASANNA NAIKODI   97  47    144
# 2   393CS20001              ABHINAV PRASANNA NAIKODI   97  47    144
# 3   393CS20002                          AKASH TORAVI   97  52    149
# 4   393CS21702              BIRADAR GURURAJ SIDHARUD   75  21     96
# 5   393CS20005                DUGIWADE PRACHI SANJAY   11  23     34
# 6   393CS21703                   GURUNATH DESHAPANDE   87  92    179
# 7   393CS20006           HARSHAD MAHAMMADSAB WALIKAR   45  78    123
# 8   393CS20007                    IRAMNAAZ JAMKHANDI   97  17    114
# 9   393CS20001              ABHINAV PRASANNA NAIKODI   97  47    144
# 10  393CS20008                   JAHID ALI BALABATTI   23  45     68
# 11  393CS20009                KRISHNA MAHADEV JADHAV   87  65    152
# 12  393CS20010                        LAXMI NAVALAGI   61  39    100
# ...
