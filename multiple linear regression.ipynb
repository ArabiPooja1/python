# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("dataset/boston_housing.csv")

# %%
a
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
plt.scatter(x="ZN",y="MEDV",data=a)

# %%
y=a.iloc[:,-1:]

# %%
y
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
x=a.iloc[:,1:-1]

# %%
x
# Out:
#        ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO       B  \
# 0    18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  396.90
# 1     0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8  396.90
# 2     0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8  392.83
# 3     0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7  394.63
# 4     0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7  396.90
# ..    ...    ...   ...    ...    ...   ...     ...  ...  ...      ...     ...
# 501   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0  391.99
# 502   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0  396.90
# 503   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0  396.90
# 504   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0  393.45
# 505   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0  396.90
#
#      LSTAT
# 0     4.98
# 1     9.14
# 2     4.03
# 3     2.94
# 4     5.33
# ..     ...
# 501   9.67
# 502   9.08
# 503   5.64
# 504   6.48
# 505   7.88
#
# [506 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=0,test_size=0.20)

# %%
xtrain
# Out:
#        ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO       B  \
# 220   0.0   6.20     1  0.507  6.951  88.5  2.8617    8  307     17.4  391.70
# 71    0.0  10.81     0  0.413  5.961  17.5  5.2873    4  305     19.2  376.94
# 240  30.0   4.93     0  0.428  6.897  54.3  6.3361    6  300     16.6  391.25
# 6    12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2  395.60
# 417   0.0  18.10     0  0.679  5.304  89.1  1.6475   24  666     20.2  127.36
# ..    ...    ...   ...    ...    ...   ...     ...  ...  ...      ...     ...
# 323   0.0   7.38     0  0.493  5.708  74.3  4.7211    5  287     19.6  391.13
# 192  45.0   3.44     0  0.437  7.178  26.3  6.4798    5  398     15.2  390.49
# 117   0.0  10.01     0  0.547  6.021  82.6  2.7474    6  432     17.8  394.51
# 47    0.0   6.91     0  0.448  6.030  85.5  5.6894    3  233     17.9  392.74
# 172   0.0   4.05     0  0.510  5.572  88.5  2.5961    5  296     16.6  396.90
#
#      LSTAT
# 220   9.71
# 71    9.88
# 240  11.38
# 6    12.43
# 417  26.64
# ..     ...
# 323  11.74
# 192   2.87
# 117  10.30
# 47   18.80
# 172  14.69
#
# [404 rows x 12 columns]

# %%
xtest
# Out:
#        ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 329   0.0   3.24     0  0.460  6.333   17.2  5.2146    4  430     16.9
# 371   0.0  18.10     0  0.631  6.216  100.0  1.1691   24  666     20.2
# 219   0.0  13.89     1  0.550  6.373   92.4  3.3633    5  276     16.4
# 403   0.0  18.10     0  0.693  5.349   96.0  1.7028   24  666     20.2
# 78    0.0  12.83     0  0.437  6.232   53.7  5.0141    5  398     18.7
# ..    ...    ...   ...    ...    ...    ...     ...  ...  ...      ...
# 56   85.0   0.74     0  0.410  6.383   35.7  9.1876    2  313     17.3
# 455   0.0  18.10     0  0.713  6.525   86.5  2.4358   24  666     20.2
# 60   25.0   5.13     0  0.453  5.741   66.2  7.2254    8  284     19.7
# 213   0.0  10.59     0  0.489  6.375   32.3  3.9454    4  277     18.6
# 108   0.0   8.56     0  0.520  6.474   97.1  2.4329    5  384     20.9
#
#           B  LSTAT
# 329  375.21   7.34
# 371  366.15   9.53
# 219  393.74  10.50
# 403  396.90  19.77
# 78   386.40  12.34
# ..      ...    ...
# 56   396.90   5.77
# 455   50.92  18.13
# 60   395.11  13.15
# 213  385.81   9.38
# 108  395.24  12.27
#
# [102 rows x 12 columns]

# %%
ytrain
# Out:
#      MEDV
# 220  26.7
# 71   21.7
# 240  22.0
# 6    22.9
# 417  10.4
# ..    ...
# 323  18.5
# 192  36.4
# 117  19.2
# 47   16.6
# 172  23.1
#
# [404 rows x 1 columns]

# %%
ytest
# Out:
#      MEDV
# 329  22.6
# 371  50.0
# 219  23.0
# 403   8.3
# 78   21.2
# ..    ...
# 56   24.7
# 455  14.1
# 60   18.7
# 213  28.1
# 108  19.8
#
# [102 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
new=LinearRegression()

# %%
new.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
pred=new.predict(xtest)

# %%
new.coef_
# Out:
# array([[ 4.11837318e-02,  1.31096477e-02,  2.51728856e+00,
#         -1.55621345e+01,  3.66391928e+00, -1.37907867e-03,
#         -1.30713245e+00,  1.80793545e-01, -1.08369442e-02,
#         -1.03988208e+00,  8.20133747e-03, -5.30419453e-01]])

# %%
new.intercept_
# Out:
# array([38.05203387])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(ytest,pred)
# Out:
# 3.857756859236011

# %%
mean_squared_error(ytest,pred)
# Out:
# 33.72155697602615

# %%
r2_score(ytest,pred)
# Out:
# 0.5858749429005743

# %%
new.score(xtest,ytest)
# Out:
# 0.5858749429005743

# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_csv("dataset/cgpa_marks_package.csv")

# %%
a
# Out:
#      cgpa  Interview_marks  package
# 0    6.89               26     3.26
# 1    5.12               38     1.98
# 2    7.82               40     3.25
# 3    7.42                8     3.67
# 4    6.94               17     3.57
# ..    ...              ...      ...
# 195  6.93               44     2.46
# 196  5.89               34     2.57
# 197  7.21               27     3.24
# 198  7.63               44     3.96
# 199  6.22               25     2.33
#
# [200 rows x 3 columns]

# %%
x=a.iloc[:,0:2]

# %%
x
# Out:
#      cgpa  Interview_marks
# 0    6.89               26
# 1    5.12               38
# 2    7.82               40
# 3    7.42                8
# 4    6.94               17
# ..    ...              ...
# 195  6.93               44
# 196  5.89               34
# 197  7.21               27
# 198  7.63               44
# 199  6.22               25
#
# [200 rows x 2 columns]

# %%
y=a.iloc[:,-1:]

# %%
y
# Out:
#      package
# 0       3.26
# 1       1.98
# 2       3.25
# 3       3.67
# 4       3.57
# ..       ...
# 195     2.46
# 196     2.57
# 197     3.24
# 198     3.96
# 199     2.33
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=0,test_size=0.20)

# %%
xtrain
# Out:
#      cgpa  Interview_marks
# 134  7.20               93
# 66   5.11               31
# 26   8.31                8
# 113  6.94               10
# 168  8.65               37
# ..    ...              ...
# 67   6.51               18
# 192  8.25               38
# 117  7.12                0
# 47   5.84               46
# 172  6.93               43
#
# [160 rows x 2 columns]

# %%
xtest
# Out:
#      cgpa  Interview_marks
# 18   6.94               27
# 170  6.22               37
# 107  6.33                9
# 98   7.69               76
# 177  7.09               40
# 182  5.88               76
# 5    7.89               23
# 146  6.07               22
# 12   8.94               16
# 152  7.37               56
# 61   5.48               86
# 125  7.33               55
# 180  6.19               29
# 154  7.08               54
# 80   7.63               46
# 7    6.75               39
# 33   6.35               27
# 130  6.68               53
# 37   5.90                9
# 74   6.85                3
# 183  7.28               18
# 145  5.84               28
# 45   7.87               10
# 159  8.71               22
# 60   5.61               31
# 123  5.10               52
# 179  7.14               45
# 185  6.31               31
# 122  5.12               51
# 44   5.09               55
# 16   6.84               19
# 55   8.20               15
# 150  6.30               22
# 111  5.42               33
# 22   6.14               54
# 189  8.11                9
# 129  7.29               39
# 4    6.94               17
# 83   8.44               20
# 106  6.13               22

# %%
ytrain
# Out:
#      package
# 134     2.83
# 66      1.63
# 26      3.42
# 113     2.37
# 168     3.52
# ..       ...
# 67      2.89
# 192     3.75
# 117     2.99
# 47      3.26
# 172     2.51
#
# [160 rows x 1 columns]

# %%
ytest
# Out:
#      package
# 18      2.98
# 170     2.87
# 107     2.59
# 98      3.83
# 177     3.64
# 182     2.08
# 5       2.99
# 146     2.46
# 12      3.65
# 152     3.08
# 61      1.61
# 125     3.16
# 180     2.72
# 154     2.85
# 80      3.44
# 7       2.48
# 33      2.73
# 130     2.49
# 37      2.43
# 74      3.44
# 183     2.72
# 145     2.18
# 45      3.58
# 159     4.08
# 60      2.19
# 123     2.30
# 179     3.03
# 185     3.18
# 122     2.01
# 44      1.86
# 16      2.35
# 55      3.39
# 150     2.73
# 111     2.25
# 22      2.30
# 189     4.06
# 129     3.12
# 4       3.57
# 83      3.49
# 106     2.19

# %%
from sklearn.linear_model import LinearRegression

# %%
new=LinearRegression()

# %%
new.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
pred=new.predict(xtest)

# %%
pred
# Out:
# array([[2.97008939],
#        [2.555232  ],
#        [2.6183676 ],
#        [3.40278329],
#        [3.05665784],
#        [2.35964487],
#        [3.5175559 ],
#        [2.46864502],
#        [4.12262656],
#        [3.21817563],
#        [2.12920974],
#        [3.19511358],
#        [2.53786826],
#        [3.05102442],
#        [3.36792602],
#        [2.86069991],
#        [2.63006085],
#        [2.82048732],
#        [2.37055019],
#        [2.91799816],
#        [3.16595462],
#        [2.33614714],
#        [3.50590901],
#        [3.99012868],
#        [2.20362145],
#        [1.90989314],
#        [3.08552016],
#        [2.60704515],
#        [1.92141026],
#        [1.90415775],
#        [2.91238328],
#        [3.69614081],
#        [2.60119852],
#        [2.09413927],
#        [2.50928402],
#        [3.64421643],
#        [3.17191248],
#        [2.9699967 ],
#        [3.83450386],
#        [2.5032242 ]])

# %%
ytest
# Out:
#      package
# 18      2.98
# 170     2.87
# 107     2.59
# 98      3.83
# 177     3.64
# 182     2.08
# 5       2.99
# 146     2.46
# 12      3.65
# 152     3.08
# 61      1.61
# 125     3.16
# 180     2.72
# 154     2.85
# 80      3.44
# 7       2.48
# 33      2.73
# 130     2.49
# 37      2.43
# 74      3.44
# 183     2.72
# 145     2.18
# 45      3.58
# 159     4.08
# 60      2.19
# 123     2.30
# 179     3.03
# 185     3.18
# 122     2.01
# 44      1.86
# 16      2.35
# 55      3.39
# 150     2.73
# 111     2.25
# 22      2.30
# 189     4.06
# 129     3.12
# 4       3.57
# 83      3.49
# 106     2.19

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mse=mean_squared_error(ytest,pred)

# %%
np.sqrt(mse)
# Out:
# 0.3197261367266628

# %%
mean_absolute_error(ytest,pred)
# Out:
# 0.2552824296141717

# %%
r2_score(ytest,pred)
# Out:
# 0.7296811169601617

# %%
new.score(xtrain,ytrain)
# Out:
# 0.7813227900491998

# %%
new.coef_
# Out:
# array([[5.76319567e-01, 9.26973414e-06]])

# %%
new.intercept_
# Out:
# array([-1.02981868])
