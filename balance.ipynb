# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_csv("titanics.csv")

# %%
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              1       0.0       3
# 2              2       NaN       1
# 3              3       NaN       3
# 4              4       NaN       1
# ..           ...       ...     ...
# 893          887       0.0       2
# 894          888       1.0       1
# 895          889       0.0       3
# 896          890       1.0       1
# 897          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1                              Braund, Mr. Owen Harris    male  22.0      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3                               Heikkinen, Miss. Laina  female   NaN      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.duplicated().sum()
# Out:
# 7

# %%
a.loc[a.duplicated(),:]
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 1              1       0.0       3  Braund, Mr. Owen Harris  male  22.0
# 8              1       0.0       3  Braund, Mr. Owen Harris  male  22.0
# 16             1       0.0       3  Braund, Mr. Owen Harris  male  22.0
# 46            17       0.0       3     Rice, Master. Eugene  male   2.0
# 150           17       0.0       3     Rice, Master. Eugene  male   2.0
# 355          339       1.0       3    Dahl, Mr. Karl Edwart  male  45.0
# 364          339       1.0       3    Dahl, Mr. Karl Edwart  male  45.0
#
#      SibSp  Parch     Ticket    Fare Cabin Embarked
# 1        1      0  A/5 21171   7.250   NaN        S
# 8        1      0  A/5 21171   7.250   NaN        S
# 16       1      0  A/5 21171   7.250   NaN        S
# 46       4      1     382652  29.125   NaN        Q
# 150      4      1     382652  29.125   NaN        Q
# 355      0      0       7598   8.050   NaN        S
# ...

# %%
a.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 2              2       NaN       1
# 3              3       NaN       3
# 4              4       NaN       1
# 5              5       0.0       3
# ..           ...       ...     ...
# 893          887       0.0       2
# 894          888       1.0       1
# 895          889       0.0       3
# 896          890       1.0       1
# 897          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3                               Heikkinen, Miss. Laina  female   NaN      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a=pd.read_csv("dataset/student.csv")

# %%
a
# Out:
#         Reg_no                                   Name
# 0   393CS20001              ABHINAV PRASANNA  NAIKODI
# 1   393CS20002                          AKASH  TORAVI
# 2   393CS21702               BIRADAR GURURAJ SIDHARUD
# 3   393CS20005                DUGIWADE PRACHI  SANJAY
# 4   393CS21703                   GURUNATH  DESHAPANDE
# 5   393CS20006           HARSHAD MAHAMMADSAB  WALIKAR
# 6   393CS20007                    IRAMNAAZ  JAMKHANDI
# 7   393CS20008                   JAHID ALI  BALABATTI
# 8   393CS20009                KRISHNA MAHADEV  JADHAV
# 9   393CS20010                        LAXMI  NAVALAGI
# 10  393CS20011                      MAIBOOBSAB  NADAF
# 11  393CS21704                   MANJU SHIVAJI CHAVAN
# 12  393CS20012                  MISBA BUDANSAB  MOMIN
# 13  393CS20013                   MODI AVADOOT  MAHESH
# 14  393CS20015                     NADAF NIHAL  NASIM
# 15  393CS20016                    NANDINI NITIN  MODI
# ...

# %%
b=pd.read_csv("dataset/marks.csv")

# %%
b
# Out:
#     PP  DSP
# 0   97   47
# 1   97   52
# 2   75   21
# 3   11   23
# 4   87   92
# 5   45   78
# 6   97   17
# 7   23   45
# 8   87   65
# 9   61   39
# 10  33   39
# 11  53   44
# 12  56   62
# 13  22   65
# 14  45   20
# 15  25   15
# 16  90   74
# 17  31   94
# 18  93    3
# 19  41   89
# 20  32   57
# 21  90   91
# 22  76   72
# 23  17   30
# 24  58   49
# 25   4   24
# 26  86   70
# 27  24   87
# 28  20   11
# 29  37   58
# 30  95   77
# 31  61   84
# 32  88   83
# 33  76   31
# 34   7   31
# 35  77   70
# 36  43   27
# 37  10   14
# 38  90   22
# 39  44   45

# %%
a.duplicated().sum()
# Out:
# 5

# %%
a.loc[a.duplicated(),:]
# Out:
#         Reg_no                      Name
# 35  393CS21702  BIRADAR GURURAJ SIDHARUD
# 36  393CS21703      GURUNATH  DESHAPANDE
# 37  393CS21704      MANJU SHIVAJI CHAVAN
# 38  393CS21706      SNEHA ASHOK DODAMANI
# 39  393CS21707          VARSHA  GALAGALI

# %%
a.drop_duplicates()
# Out:
#         Reg_no                                   Name
# 0   393CS20001              ABHINAV PRASANNA  NAIKODI
# 1   393CS20002                          AKASH  TORAVI
# 2   393CS21702               BIRADAR GURURAJ SIDHARUD
# 3   393CS20005                DUGIWADE PRACHI  SANJAY
# 4   393CS21703                   GURUNATH  DESHAPANDE
# 5   393CS20006           HARSHAD MAHAMMADSAB  WALIKAR
# 6   393CS20007                    IRAMNAAZ  JAMKHANDI
# 7   393CS20008                   JAHID ALI  BALABATTI
# 8   393CS20009                KRISHNA MAHADEV  JADHAV
# 9   393CS20010                        LAXMI  NAVALAGI
# 10  393CS20011                      MAIBOOBSAB  NADAF
# 11  393CS21704                   MANJU SHIVAJI CHAVAN
# 12  393CS20012                  MISBA BUDANSAB  MOMIN
# 13  393CS20013                   MODI AVADOOT  MAHESH
# 14  393CS20015                     NADAF NIHAL  NASIM
# 15  393CS20016                    NANDINI NITIN  MODI
# ...

# %%
df=pd.concat([a,b],axis=1)

# %%
df
# Out:
#         Reg_no                                   Name  PP  DSP
# 0   393CS20001              ABHINAV PRASANNA  NAIKODI  97   47
# 1   393CS20002                          AKASH  TORAVI  97   52
# 2   393CS21702               BIRADAR GURURAJ SIDHARUD  75   21
# 3   393CS20005                DUGIWADE PRACHI  SANJAY  11   23
# 4   393CS21703                   GURUNATH  DESHAPANDE  87   92
# 5   393CS20006           HARSHAD MAHAMMADSAB  WALIKAR  45   78
# 6   393CS20007                    IRAMNAAZ  JAMKHANDI  97   17
# 7   393CS20008                   JAHID ALI  BALABATTI  23   45
# 8   393CS20009                KRISHNA MAHADEV  JADHAV  87   65
# 9   393CS20010                        LAXMI  NAVALAGI  61   39
# 10  393CS20011                      MAIBOOBSAB  NADAF  33   39
# 11  393CS21704                   MANJU SHIVAJI CHAVAN  53   44
# 12  393CS20012                  MISBA BUDANSAB  MOMIN  56   62
# 13  393CS20013                   MODI AVADOOT  MAHESH  22   65
# ...

# %%
df["total"]=df["PP"]+df["DSP"]

# %%
df
# Out:
#         Reg_no                                   Name  PP  DSP  total
# 0   393CS20001              ABHINAV PRASANNA  NAIKODI  97   47    144
# 1   393CS20002                          AKASH  TORAVI  97   52    149
# 2   393CS21702               BIRADAR GURURAJ SIDHARUD  75   21     96
# 3   393CS20005                DUGIWADE PRACHI  SANJAY  11   23     34
# 4   393CS21703                   GURUNATH  DESHAPANDE  87   92    179
# 5   393CS20006           HARSHAD MAHAMMADSAB  WALIKAR  45   78    123
# 6   393CS20007                    IRAMNAAZ  JAMKHANDI  97   17    114
# 7   393CS20008                   JAHID ALI  BALABATTI  23   45     68
# 8   393CS20009                KRISHNA MAHADEV  JADHAV  87   65    152
# 9   393CS20010                        LAXMI  NAVALAGI  61   39    100
# 10  393CS20011                      MAIBOOBSAB  NADAF  33   39     72
# 11  393CS21704                   MANJU SHIVAJI CHAVAN  53   44     97
# ...

# %%
df["per"]=df["total"]/200*100

# %%
df
# Out:
#         Reg_no                                   Name  PP  DSP  total   per
# 0   393CS20001              ABHINAV PRASANNA  NAIKODI  97   47    144  72.0
# 1   393CS20002                          AKASH  TORAVI  97   52    149  74.5
# 2   393CS21702               BIRADAR GURURAJ SIDHARUD  75   21     96  48.0
# 3   393CS20005                DUGIWADE PRACHI  SANJAY  11   23     34  17.0
# 4   393CS21703                   GURUNATH  DESHAPANDE  87   92    179  89.5
# 5   393CS20006           HARSHAD MAHAMMADSAB  WALIKAR  45   78    123  61.5
# 6   393CS20007                    IRAMNAAZ  JAMKHANDI  97   17    114  57.0
# 7   393CS20008                   JAHID ALI  BALABATTI  23   45     68  34.0
# 8   393CS20009                KRISHNA MAHADEV  JADHAV  87   65    152  76.0
# 9   393CS20010                        LAXMI  NAVALAGI  61   39    100  50.0
# 10  393CS20011                      MAIBOOBSAB  NADAF  33   39     72  36.0
# ...

# %%
a=pd.DataFrame([
    ["393CS20020","Rahul",34,45,112,34.5]
],columns=["Reg_no","Name","PP","DSP","total","per"])

# %%
a
# Out:
#        Reg_no   Name  PP  DSP  total   per
# 0  393CS20020  Rahul  34   45    112  34.5

# %%
df.append(a)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_9376\688406051.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(a)
#         Reg_no                                   Name  PP  DSP  total   per
# 0   393CS20001              ABHINAV PRASANNA  NAIKODI  97   47    144  72.0
# 1   393CS20002                          AKASH  TORAVI  97   52    149  74.5
# 2   393CS21702               BIRADAR GURURAJ SIDHARUD  75   21     96  48.0
# 3   393CS20005                DUGIWADE PRACHI  SANJAY  11   23     34  17.0
# 4   393CS21703                   GURUNATH  DESHAPANDE  87   92    179  89.5
# 5   393CS20006           HARSHAD MAHAMMADSAB  WALIKAR  45   78    123  61.5
# 6   393CS20007                    IRAMNAAZ  JAMKHANDI  97   17    114  57.0
# 7   393CS20008                   JAHID ALI  BALABATTI  23   45     68  34.0
# 8   393CS20009                KRISHNA MAHADEV  JADHAV  87   65    152  76.0
# ...

# %%
a=pd.read_csv("titanics.csv")

# %%
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              1       0.0       3
# 2              2       NaN       1
# 3              3       NaN       3
# 4              4       NaN       1
# ..           ...       ...     ...
# 893          887       0.0       2
# 894          888       1.0       1
# 895          889       0.0       3
# 896          890       1.0       1
# 897          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1                              Braund, Mr. Owen Harris    male  22.0      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3                               Heikkinen, Miss. Laina  female   NaN      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False      True   False  False  False  False  False  False   False
# 3          False      True   False  False  False   True  False  False   False
# 4          False      True   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 893        False     False   False  False  False  False  False  False   False
# 894        False     False   False  False  False  False  False  False   False
# 895        False     False   False  False  False   True  False  False   False
# 896        False     False   False  False  False  False  False  False   False
# 897        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
a.isna().sum()
# Out:
# PassengerId      0
# Survived         4
# Pclass           0
# Name             0
# Sex              0
# Age            178
# SibSp            0
# Parch            0
# Ticket           0
# Fare             3
# Cabin          694
# Embarked         2
# dtype: int64

# %%
a.isnull().sum()
# Out:
# PassengerId      0
# Survived         4
# Pclass           0
# Name             0
# Sex              0
# Age            178
# SibSp            0
# Parch            0
# Ticket           0
# Fare             3
# Cabin          694
# Embarked         2
# dtype: int64

# %%
a.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False      True   False  False  False  False  False  False   False
# 3          False      True   False  False  False   True  False  False   False
# 4          False      True   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 893        False     False   False  False  False  False  False  False   False
# 894        False     False   False  False  False  False  False  False   False
# 895        False     False   False  False  False   True  False  False   False
# 896        False     False   False  False  False  False  False  False   False
# 897        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
a.info("")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  898 non-null    int64
#  1   Survived     894 non-null    float64
#  2   Pclass       898 non-null    int64
#  3   Name         898 non-null    object
#  4   Sex          898 non-null    object
#  5   Age          720 non-null    float64
#  6   SibSp        898 non-null    int64
#  7   Parch        898 non-null    int64
#  8   Ticket       898 non-null    object
#  9   Fare         895 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     896 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 84.3+ KB

# %%
a.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True     False    True  True  True   True   True   True    True
# 3           True     False    True  True  True  False   True   True    True
# 4           True     False    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 893         True      True    True  True  True   True   True   True    True
# 894         True      True    True  True  True   True   True   True    True
# 895         True      True    True  True  True  False   True   True    True
# 896         True      True    True  True  True   True   True   True    True
# 897         True      True    True  True  True   True   True   True    True
#
#       Fare  Cabin  Embarked
# ...

# %%
a.notnull().sum()
# Out:
# PassengerId    898
# Survived       894
# Pclass         898
# Name           898
# Sex            898
# Age            720
# SibSp          898
# Parch          898
# Ticket         898
# Fare           895
# Cabin          204
# Embarked       896
# dtype: int64

# %%
a.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 7              7       0.0       1
# 12            11       1.0       3
# 13            12       1.0       1
# 24            22       1.0       2
# 26            24       1.0       1
# ..           ...       ...     ...
# 878          872       1.0       1
# 879          873       0.0       1
# 886          880       1.0       1
# 894          888       1.0       1
# 896          890       1.0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 7                             McCarthy, Mr. Timothy J    male  54.0      0
# 12                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 13                           Bonnell, Miss. Elizabeth  female  58.0      0
# 24                              Beesley, Mr. Lawrence    male  34.0      0
# 26                       Sloper, Mr. William Thompson    male  28.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
a.dropna(axis=1)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              1       3                            Braund, Mr. Owen Harris
# 2              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3              3       3                             Heikkinen, Miss. Laina
# 4              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ..           ...     ...                                                ...
# 893          887       2                              Montvila, Rev. Juozas
# 894          888       1                       Graham, Miss. Margaret Edith
# 895          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 896          890       1                              Behr, Mr. Karl Howell
# 897          891       3                                Dooley, Mr. Patrick
#
#         Sex  SibSp  Parch            Ticket
# ...

# %%
a.dropna(thresh=10)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              1       0.0       3
# 2              2       NaN       1
# 4              4       NaN       1
# 5              5       0.0       3
# ..           ...       ...     ...
# 893          887       0.0       2
# 894          888       1.0       1
# 895          889       0.0       3
# 896          890       1.0       1
# 897          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1                              Braund, Mr. Owen Harris    male  22.0      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.dropna(inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(a["Sex"])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(a["Survived"])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(a["Embarked"])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
plt.pie(a["Survived"].value_counts(),autopct='%1.1f%%')
plt.show()

# %%
plt.pie(a["Sex"].value_counts(),autopct='%1.1f%%')
plt.show()

# %%
plt.pie(a["Embarked"].value_counts(),autopct='%1.1f%%')
plt.show()

# %%
sns.histplot(a["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.kdeplot(a["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.histplot(a["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.distplot(a["Age"])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(a["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>
